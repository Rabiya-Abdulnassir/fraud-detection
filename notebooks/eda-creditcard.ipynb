# %%
import pandas as pd

# =========================
# LOAD DATA
# =========================
cc_df = pd.read_csv("../data/raw/creditcard.csv")

# =========================
# BASIC INFO
# =========================
print(cc_df.shape)
print(cc_df.info())

# =========================
# CLASS IMBALANCE
# =========================
print(cc_df["Class"].value_counts())
print(cc_df["Class"].value_counts(normalize=True) * 100)

# =========================
# MISSING VALUES
# =========================
print(cc_df.isnull().sum())

# =========================
# STATISTICS
# =========================
print(cc_df.describe())
